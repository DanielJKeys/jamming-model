# %% [markdown]
# #Setup

# %% [markdown]
# User Variables

# %%
RESOLUTION = 2
SPHERE_RESOLUTION = 10
LAYERS = 3
MIN_SIGNAL = 5 #Minimum db required to communicate
DEFAULT_OPACITY = 1/(LAYERS+1)
X_MAX, Y_MAX, Z_MAX, F_MAX, db_MAX = [10,10,10, 5, 200]
FILE_LOCATION = "./Sample_Jam.csv"

# %% [markdown]
# #Imports & Drive Mounting

# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import numpy as np
import math
import random
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# #Functions

# %% [markdown]
# Creates a point map for a sphere to be graphed as a plotly surface

# %%
def plotly_sphere(x_dim, y_dim, z_dim, r_dim, resolution=SPHERE_RESOLUTION):
    u, v = np.mgrid[0:2 * np.pi:resolution * 2j, 0:np.pi:resolution * 1j]
    X_range = r_dim * np.cos(u) * np.sin(v) + x_dim
    Y_range = r_dim * np.sin(u) * np.sin(v) + y_dim
    Z_range = r_dim * np.cos(v) + z_dim
    return X_range, Y_range, Z_range

# %%
def on_remove_clicked(_):
  print(f"Node Removed:")
  nodes[-1].print()
  del nodes[-1]

# %%
def on_add_clicked(_):
  nodes.append(Node(origin_x=Xslider.value, origin_y=Yslider.value, origin_z=Zslider.value, frequency=Fslider.value, db=dbslider.value, stype=Tradio.value))
  print(f"Node Added:")
  nodes[-1].print()

# %%
def on_simple_graph_clicked(_):
  data = []
  for node in nodes:
    data = data + node.graph()

  fig = go.Figure(data=data)

  fig.update_traces(showscale=False)
  fig.update_layout(
    showlegend=False,
    autosize=False,
    width=1500,
    height=1000,
    paper_bgcolor="LightSteelBlue",
  )

  fig.show()

# %%
def on_complex_graph_clicked(_):
    """Generate complex 3D visualization of net signal strengths."""
    # Vectorized grid computation for better performance
    x_coords = np.arange(0, X_MAX, 1/RESOLUTION)
    y_coords = np.arange(0, Y_MAX, 1/RESOLUTION)
    z_coords = np.arange(0, Z_MAX, 1/RESOLUTION)
    X_grid, Y_grid, Z_grid = np.meshgrid(x_coords, y_coords, z_coords, indexing='ij')

    node_grid = np.zeros_like(X_grid)

    for node in nodes:
        distances = np.sqrt((X_grid - node.x)**2 + (Y_grid - node.y)**2 + (Z_grid - node.z)**2)
        signals = node.signal_strength_db(distances)
        if node.t == 'jam':
            node_grid -= signals
        elif node.t == 'com':
            node_grid += signals

    # Extract data points
    jam_mask = node_grid < 0
    com_mask = node_grid > 0

    data_x_jam = X_grid[jam_mask]
    data_y_jam = Y_grid[jam_mask]
    data_z_jam = Z_grid[jam_mask]
    data_value_jam = -node_grid[jam_mask]

    data_x_com = X_grid[com_mask]
    data_y_com = Y_grid[com_mask]
    data_z_com = Z_grid[com_mask]
    data_value_com = node_grid[com_mask]

    data = [
        go.Scatter3d(
            x=data_x_jam, y=data_y_jam, z=data_z_jam, mode='markers',
            marker=dict(size=6, color=data_value_jam, colorscale=["rgb(255, 204, 203)", "red"], opacity=0.5),
            hovertemplate='x: %{x:.2f}<br>y: %{y:.2f}<br>z: %{z:.2f}<br>Signal: %{text}',
            text=[f'{v:.2f}' for v in data_value_jam]
        ),
        go.Scatter3d(
            x=data_x_com, y=data_y_com, z=data_z_com, mode='markers',
            marker=dict(size=6, color=data_value_com, colorscale=["rgb(173,216,230)", "blue"], opacity=0.5),
            hovertemplate='x: %{x:.2f}<br>y: %{y:.2f}<br>z: %{z:.2f}<br>Signal: %{text}',
            text=[f'{v:.2f}' for v in data_value_com]
        )
    ]

    fig = go.Figure(data=data)
    fig.update_layout(
        showlegend=False, autosize=False, width=1500, height=1000,
        paper_bgcolor="LightSteelBlue",
        scene=dict(
            xaxis_title='X', yaxis_title='Y', zaxis_title='Z'
        )
    )
    fig.show()

# %% [markdown]
# #Node Class

# %% [markdown]
# **SIGNAL STRENGTH**
#
# FSPL (dB) = 20log10(d) + 20log10(f) + K
#
# d = distance
# f = frequency
# K= constant that depends on the units used for d and f
# If d is measured in kilometers, f in MHz, the formula is:
#
# FSPL (dB) = 20log10(d)+ 20log10(f) + 32.44

# %%
class Node:
    """
    Represents a communication or jamming node with signal strength calculations.
    """
    def __init__(self, origin_x, origin_y, origin_z, frequency, db, stype="jam", min_signal=MIN_SIGNAL):
        self.x = origin_x
        self.y = origin_y
        self.z = origin_z
        self.f = frequency * 1000  # Convert to MHz assuming input in GHz
        self.db = db
        self.t = stype.lower()
        self.rec_min = min_signal
        self.r = self.signal_strength_min()

    def graph(self):
        """Generate plotly surfaces for visualizing the node's signal sphere."""
        data = []
        color = "blue" if self.t == "com" else "red"
        for radius in np.linspace(0, self.r, LAYERS + 1):
            X, Y, Z = plotly_sphere(self.x, self.y, self.z, radius)
            data.append(go.Surface(x=X, y=Y, z=Z, opacity=DEFAULT_OPACITY, colorscale=[color, color], showlegend=False, showscale=False))
        return data

    def print(self):
        """Print node details."""
        print(f"X: {self.x}, Y: {self.y}, Z: {self.z}, Radius: {self.r}")

    def signal_strength_min(self):
        """Calculate minimum radius for communication based on min signal."""
        fspl = abs(self.db) - 20 * math.log10(abs(self.f)) - 32.4 - self.rec_min
        return 10 ** (fspl / 20)

    def signal_strength_db(self, distance):
        """Calculate received signal strength in dB at a given distance."""
        if distance == 0:
            distance = 1 / RESOLUTION
        fspl = 20 * math.log10(distance) + 20 * math.log10(abs(self.f)) + 32.4
        return abs(self.db) - fspl

    def distance_finder(self, x, y, z):
        """Calculate Euclidean distance to a point."""
        return math.sqrt((self.x - x) ** 2 + (self.y - y) ** 2 + (self.z - z) ** 2)

# %% [markdown]
# #Widgets

# %% [markdown]
# Initalize the Spheres from Data

# %%
try:
    df = pd.read_csv(FILE_LOCATION)
    nodes = []
    for i, row in df.iterrows():
        nodes.append(Node(row['X'], row['Y'], row['Z'], row["frequency"], row["db"], row["Type"]))
    print(f"Loaded {len(nodes)} nodes from {FILE_LOCATION}")
except FileNotFoundError:
    print(f"Error: {FILE_LOCATION} not found. Please ensure the CSV file exists.")
    nodes = []
except Exception as e:
    print(f"Error loading CSV: {e}")
    nodes = []
# Out:
# Loaded 3 nodes from ./Sample_Jam.csv

# %%
Xslider = widgets.IntSlider(min=0, max=X_MAX, step=1, description='X:', value=round(X_MAX/2))
Yslider = widgets.IntSlider(min=0, max=Y_MAX, step=1, description='Y:', value=round(Y_MAX/2))
Zslider = widgets.IntSlider(min=0, max=Z_MAX, step=1, description='Z:', value=round(Z_MAX/2))
Fslider = widgets.FloatSlider(min=0, max=F_MAX, step=.1, description='Freq:', value=2.5)
dbslider = widgets.IntSlider(min=0, max=db_MAX, step=1, description='dB:', value=100)
Tradio = widgets.RadioButtons(options=['Com', 'Jam'], value='Com', description='Type:')

addButton = widgets.Button(description='Add Node', button_style='success', tooltip='Add a node to the graph')
addButton.on_click(on_add_clicked)

removeButton = widgets.Button(description='Remove Last Node', button_style='danger', tooltip='Remove the last node')
removeButton.on_click(on_remove_clicked)

simple_graphButton = widgets.Button(description='Simple Graph', button_style='info', tooltip='Show spheres')
simple_graphButton.on_click(on_simple_graph_clicked)

complex_graphButton = widgets.Button(description='Complex Graph', button_style='primary', tooltip='Show net signals')
complex_graphButton.on_click(on_complex_graph_clicked)

# Display widgets
display(Xslider, Yslider, Zslider, Fslider, dbslider, Tradio, addButton, removeButton, simple_graphButton, complex_graphButton)
# Out:
# IntSlider(value=5, description='X:', max=10)
# IntSlider(value=5, description='Y:', max=10)
# IntSlider(value=5, description='Z:', max=10)
# FloatSlider(value=2.5, description='Freq:', max=5.0)
# IntSlider(value=100, description='dB:', max=200)
# RadioButtons(description='Type:', options=('Com', 'Jam'), value='Com')
# Button(button_style='success', description='Add Node', style=ButtonStyle(), tooltip='Add a node to the graph')
# Button(button_style='danger', description='Remove Last Node', style=ButtonStyle(), tooltip='Remove the last no…
# Button(button_style='info', description='Simple Graph', style=ButtonStyle(), tooltip='Show spheres')
# Button(button_style='primary', description='Complex Graph', style=ButtonStyle(), tooltip='Show net signals')

# %% [markdown]
# #Graph

# %% [markdown]
# Visualization of Overlap

# %%
data_x_jam, data_y_jam, data_z_jam, data_value_jam = [],[],[],[]
data_x_com, data_y_com, data_z_com, data_value_com = [],[],[],[]

node_grid = np.zeros((X_MAX * RESOLUTION,Y_MAX * RESOLUTION,Z_MAX * RESOLUTION))
for x in range(0,X_MAX * RESOLUTION):
  for y in range(0, Y_MAX * RESOLUTION):
    for z in range(0, Z_MAX * RESOLUTION):
      for node in nodes:
        distance = node.distance_finder(x/RESOLUTION,y/RESOLUTION,z/RESOLUTION)

        signal = node.signal_strength_db(distance)
          #if signal > 0:
          #  node.print()
          #  print(f"X:{x}, Y:{y}, Z:{z}, Signal:{signal}\n")
        if node.t == 'jam' and signal > 0:
          node_grid[x,y,z] = node_grid[x,y,z] - node.signal_strength_db(distance)
        elif node.t == 'com' and signal > 0:
          node_grid[x,y,z] = node_grid[x,y,z] + node.signal_strength_db(distance)

# %%
for x in range(0,X_MAX * RESOLUTION):
  for y in range(0, Y_MAX * RESOLUTION):
    for z in range(0, Z_MAX * RESOLUTION):
      if node_grid[x,y,z] < 0:
        #print(f"X:{x/2}, Y:{y/2}, Z:{z/2}, Signal:{node_grid[x,y,z]}")
        data_x_jam.append(x/RESOLUTION)
        data_y_jam.append(y/RESOLUTION)
        data_z_jam.append(z/RESOLUTION)
        data_value_jam.append(-node_grid[x,y,z])

      elif node_grid[x,y,z] > 0:
        data_x_com.append(x/RESOLUTION)
        data_y_com.append(y/RESOLUTION)
        data_z_com.append(z/RESOLUTION)
        data_value_com.append(node_grid[x,y,z])

# %% [markdown]
# Visualization of Spheres

# %%
data = [go.Scatter3d(x= data_x_jam, y= data_y_jam, z= data_z_jam, mode ='markers',
                                    marker=dict(
                                      size=12,
                                      color=data_value_jam,
                                      colorscale=["rgb(255, 204, 203)", "red"]),
                                      opacity=.25,
                                      hovertemplate = 'y: %{y}'+'<br>x: %{x}'+'<br>z: %{z}<br>'+'%{text}',
                                      text = [f'Signal: {round(i,2)}' for i in data_value_jam]),
        go.Scatter3d(x= data_x_com, y= data_y_com, z= data_z_com, mode ='markers',
                                    marker=dict(
                                      size=12,
                                      color=data_value_com,
                                      colorscale=["rgb(173,216,230)","blue"]),
                                    opacity=.25,
                                    hovertemplate = 'y: %{y}'+'<br>x: %{x}'+'<br>z: %{z}<br>'+'%{text}',
                                    text = [f'Signal: {round(i,2)}' for i in data_value_com])]

fig = go.Figure(data=data)
fig.update_layout(
    showlegend=False,
    autosize=False,
    width=1500,
    height=1000,
    paper_bgcolor="LightSteelBlue",
)
fig.show()

# %% [markdown]
# # Modeling Automation

# %%
    def place_node(self, start=0):
        """Place a new communication node, adjusting position based on signal."""
        if len(self.nodes) == 0:
            y = random.randint(0, Y_MAX * self.res) / self.res
            z = random.randint(0, Z_MAX * self.res) / self.res
            self.nodes.append(Node(0, y, z, self.f, self.db, "com", MIN_SIGNAL))
            return

        X, Y, Z = plotly_sphere(self.nodes[-1].x, self.nodes[-1].y, self.nodes[-1].z, self.nodes[-1].r)
        i = random.randint(0, len(X) - 1)
        j = random.randint(0, len(X[i]) - 1)
        counter = 0
        while X[i][j] < 0 or X[i][j] > X_MAX or Y[i][j] < 0 or Y[i][j] > Y_MAX or Z[i][j] < 0 or Z[i][j] > Z_MAX:
            if counter > 1000:
                # Fallback: place randomly within bounds
                x_pos = self.nodes[-1].x if self.nodes[-1].x > 0 else 0
                y_pos = random.randint(0, Y_MAX * self.res) / self.res
                z_pos = random.randint(0, Z_MAX * self.res) / self.res
                self.nodes.append(Node(x_pos, y_pos, z_pos, self.f, self.db, "com", MIN_SIGNAL))
                return
            i = random.randint(0, len(X) - 1)
            j = random.randint(0, len(X[i]) - 1)
            counter += 1

        # Exponential signal adjustment for better convergence
        grid_x = max(0, min(round(X[i][j] * self.res), X_MAX * self.res - 1))
        grid_y = max(0, min(round(Y[i][j] * self.res), Y_MAX * self.res - 1))
        grid_z = max(0, min(round(Z[i][j] * self.res), Z_MAX * self.res - 1))
        signal = self.signal_grid[grid_x, grid_y, grid_z]
        adjustment = signal * 0.1  # Dampen the adjustment
        x_pos = X[i][j] + adjustment
        self.nodes.append(Node(max(0, min(x_pos, X_MAX)), Y[i][j], Z[i][j], self.f, self.db, "com", MIN_SIGNAL))

# %%
class Simulation:
    """
    Runs multiple simulations to find the optimal model with fewest nodes.
    """
    def __init__(self, signal_grid, com_freq, com_db, goal_x=X_MAX, x_grid=X_MAX, y_grid=Y_MAX, z_grid=Z_MAX, res=RESOLUTION):
        self.x = x_grid
        self.y = y_grid
        self.z = z_grid
        self.res = res
        self.f = com_freq
        self.db = com_db
        self.goal_x = goal_x
        self.signal_grid = signal_grid.copy()
        self.ideal_model = None

    def run(self, iterations=1000):
        """Run simulations and return the best model."""
        for iteration in range(iterations):
            print(f"Iteration {iteration + 1}")

            m = Model(self.signal_grid, self.f, self.db, self.goal_x, self.x, self.y, self.z, self.res)

            m.place_node()
            m.nodes[-1].print()
            m.update_grid()

            while not m.check_goal():
                m.place_node()
                m.nodes[-1].print()
                m.update_grid()

            if self.ideal_model is None or len(m.nodes) < len(self.ideal_model.nodes):
                self.ideal_model = m
        return self.ideal_model

# %%
if 'node_grid' in globals():
    sim = Simulation(node_grid, 1.5, 115)
    ideal_model = sim.run(5)  # Reduced iterations for testing
    print("IDEAL MODEL:")
    ideal_model.print()
else:
    print("Error: node_grid not found. Please run the complex graph first.")
# Out:
# Iteration 1
# X: 0, Y: 6.0, Z: 4.0, Radius: 5.057183833527892
# X: 6.592280810538936, Y: 7.6171182507887405, Z: 4.87817075681878, Radius: 5.057183833527892
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 3
#       1 sim = Simulation(node_grid,1.5,115)
#       2
# ----> 3 ideal_model = sim.run(10)
#       4 print("IDEAL MODEL:")
#       5 ideal_model.print()
#
# Cell In[28], line 28, in Simulation.run(self, iterations)
#      24             m.nodes[-1].print()
#      25             m.update_grid()
#      26
#      27             while not m.check_goal():
# ---> 28                 m.place_node()
#      29                 m.nodes[-1].print()
#      30                 m.update_grid()
#      31
#
# Cell In[27], line 42, in Model.place_node(self, start)
#      38             j = random.randint(0, len(X[i]) - 1)
#      39             counter += 1
#      40
# ...
